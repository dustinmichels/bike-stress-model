# %%
import sys; sys.path.insert(0, '..')

# %%
import osmnx as ox
import pandas as pd
import geopandas as gpd
import fiona

# %%
gdf = gpd.read_file("../data/model/bike-infrastructure.geojson")

# %%
gdf
