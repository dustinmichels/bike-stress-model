# %%
import sys; sys.path.insert(0, '..')

# %%
import osmnx as ox
import pandas as pd
import geopandas as gpd
import fiona

# %%
gdf = gpd.read_file("../data/model/bike-infrastructure.geojson")
# Out:
# Skipping field name: unsupported OGR type: 5
# Skipping field lanes_0: unsupported OGR type: 5
# Skipping field maxspeed_0: unsupported OGR type: 5
# Skipping field street_0: unsupported OGR type: 5

# %%
gdf
# Out:
#          u     v  key  lanes_int  maxspeed_int separation_level  \
# 0        0     1    0        2.0          20.0             none
# 1        0     2    0        2.0          20.0             none
# 2        0     3    0        NaN          20.0             none
# 3        1     4    0        2.0          20.0             none
# 4        1     0    0        2.0          20.0             none
# ...    ...   ...  ...        ...           ...              ...
# 3383  1642  1606    0        NaN          20.0             none
# 3384  1612  1611    0        NaN           NaN         separate
# 3385  1625  1626    0        1.0          20.0             none
# 3386  1628  1634    0        2.0          25.0             none
# 3387  1628  1627    0        2.0          25.0             none
#
#      street_classification  width_float  width_half  \
# 0              residential         15.2         7.6
# 1              residential         15.2         7.6
# 2              residential         10.0         5.0
# 3              residential         15.2         7.6
# 4              residential         15.2         7.6
# ...                    ...          ...         ...
# 3383           residential         10.0         5.0
# 3384        dedicated_path          3.0         1.5
# 3385           residential         12.2         6.1
# 3386           residential         15.2         7.6
# 3387           residential         15.2         7.6
#
#                                                geometry
# 0     LINESTRING (-71.0939 42.38221, -71.09354 42.38...
# 1     LINESTRING (-71.0939 42.38221, -71.09396 42.38...
# 2     LINESTRING (-71.0939 42.38221, -71.09387 42.38...
# 3     LINESTRING (-71.09332 42.38181, -71.09324 42.3...
# 4     LINESTRING (-71.09332 42.38181, -71.0934 42.38...
# ...                                                 ...
# 3383  LINESTRING (-71.08355 42.38283, -71.08391 42.3...
# 3384  LINESTRING (-71.08597 42.37856, -71.08654 42.3...
# 3385  LINESTRING (-71.0904 42.37876, -71.0906 42.37956)
# 3386  LINESTRING (-71.08755 42.37956, -71.08819 42.3...
# 3387  LINESTRING (-71.08755 42.37956, -71.08745 42.3...
#
# [3388 rows x 10 columns]
